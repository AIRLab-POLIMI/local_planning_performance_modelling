# %%
from IPython.core.display import Markdown, display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

import traceback
import numpy as np
import scipy.stats as ss
import yaml
import itertools
import sys
import os
import subprocess
from os import path
import pickle
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

from sklearn.linear_model import LinearRegression, TheilSenRegressor, RANSACRegressor, HuberRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import make_pipeline

def printmd(*args):
    display(Markdown(' '.join(map(str, args))))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#!{"ros2 run local_planning_performance_modelling compute_metrics -s"}

# %%
df = pd.read_csv(path.expanduser("~/ds/performance_modelling/output/test_local_planning/results.csv"))
with open(path.expanduser("~/ds/performance_modelling/output/test_local_planning/results_info.yaml")) as results_info_file:
    results_info = yaml.safe_load(results_info_file)

df = df[df.amcl_alpha_factor.notna()]

# turn odometry_error into alpha_1..4
results_info['run_parameter_names'] += ['alpha_1', 'alpha_2', 'alpha_3', 'alpha_4']
results_info['run_parameter_names'].remove('odometry_error')
for i in range(0, 4):
    df[f'alpha_{i+1}'] = df['odometry_error'].apply(lambda x: eval(x)[i])
del df['odometry_error']

# df.loc[df.robot_model == 'turtlebot3_waffle_performance_modelling', 'robot_model'] = 'turtle'
# df.loc[df.robot_model == 'hunter2', 'robot_model'] = 'hunter'

run_parameters = [c for c in list(df.columns) if c in results_info['run_parameter_names']]
metrics_versions = [c for c in list(df.columns) if '_version' in c]
everything_else = ['run_id', 'session_id', 'run_number']
metrics = [c for c in df.columns if c not in metrics_versions + run_parameters + everything_else]
metrics_and_versions = [c for c in list(df.columns) if '_version' in c or c in metrics]

cpu_time_metrics = [c for c in metrics if 'cpu_time' in c]
max_memory_metrics = [c for c in metrics if 'max_memory' in c]
odometry_metrics = [c for c in metrics if 'odometry_error_alpha_' in c]
odometry_mean_metrics = [c for c in metrics if 'odometry_error_alpha_' in c and '_mean' in c]
odometry_std_metrics = [c for c in metrics if 'odometry_error_alpha_' in c and '_std' in c]
odometry_parameters = [f'alpha_{i}' for i in range(1, 5)]
localization_update_metrics = [c for c in metrics if 'localization_update_' in c]
localization_update_mean_metrics = [c for c in metrics if 'localization_update_' in c and '_mean' in c]
localization_update_translation_mean_metrics = [c for c in metrics if 'localization_update_' in c and '_translation_' in c and '_mean' in c]
navigation_metrics = [c for c in metrics if c in ['trajectory_length', 'execution_time', 'success_rate']]

# add useful parameters
df['session_id'] =  df['run_id'].apply(lambda x:  x.split('_')[1]+'_'+x.split('_')[2]+'_'+x.split('_')[3])
df['run_number'] =  df['run_id'].apply(lambda x:  int(x.split('_')[5]))
df[max_memory_metrics] = df[max_memory_metrics]/1024**2
df.max_steering_angle_deg = df.max_steering_angle_deg.fillna(90)

printmd("## Number of Runs")
printmd(f"    {len(df.run_id.unique())}")

printmd("## Run Parameters")
for name in run_parameters:
    values = list(df[name].unique())
    printmd(f"    {name:<70}", sorted(values))

printmd("## Metrics")
for name in metrics_and_versions:
    if name in metrics_versions:
        if len(df[name].unique()) == 1:
            printmd(f"    {name:<70} {sorted(df[name].unique())}")
        else:
            printmd(f"<code><font style='background-color:yellow;font-family:monospace'>{name:<70}{sorted(df[name].unique())} </font></code> ⚠️")
    else:
        printmd(f"    {name:<70} min: {df[name].min(skipna=True):10.4g} {'avg':>15}: {df[name].mean(skipna=True):10.4g} {'max':>15}: {df[name].max(skipna=True):10.4g}]")
# Out:
# ## Number of Runs
#     1837
# ## Run Parameters
#     amcl_alpha_factor                                                      [0.0, 0.5, 0.75, 1.0, 1.5, 2.0]
#     environment_name                                                       ['7A-2', 'airlab', 'fr079', 'intel', 'mexico', 'office_b']
#     global_planner_node                                                    ['navfn', 'smac']
#     local_planner_node                                                     ['dwb', 'rpp', 'teb']
#     localization_node                                                      ['amcl']
#     max_steering_angle_deg                                                 [20.0, 40.0, 90.0]
#     robot_model                                                            ['hunter2', 'turtlebot3_waffle_performance_modelling']
#     run_index                                                              [0, 1]
#     alpha_1                                                                [0.0, 0.02, 0.05, 0.1]
#     alpha_2                                                                [0.0]
#     alpha_3                                                                [0.0, 0.02, 0.05, 0.1]
#     alpha_4                                                                [0.0]
# ## Metrics
#     controller_cpu_time                                                    min:       0.82             avg:      117.9             max:       1031]
#     planner_cpu_time                                                       min:       0.32             avg:      32.72             max:      317.3]
#     system_cpu_time                                                        min:       3.27             avg:      163.8             max:       1303]
#     controller_max_memory                                                  min:      22.73             avg:      62.31             max:      78.79]
#     planner_max_memory                                                     min:      25.05             avg:       1193             max:  3.109e+04]
#     system_max_memory                                                      min:      137.6             avg:       1380             max:  3.126e+04]
#     cpu_time_and_max_memory_version                                        [1]
#     trajectory_length                                                      min:          0             avg:      19.61             max:      133.9]
#     trajectory_length_version                                              [1]
#     execution_time                                                         min:      0.294             avg:      88.16             max:      648.1]
#     execution_time_version                                                 [1]
#     success_rate                                                           min:          0             avg:     0.6228             max:          1]
#     success_rate_version                                                   [1]
#     odometry_error_alpha_1_mean                                            min:   1.43e-17             avg:     0.0619             max:      4.194]
#     odometry_error_alpha_1_std                                             min:          0             avg:    0.09467             max:       13.9]
#     odometry_error_alpha_2_mean                                            min:  4.546e-18             avg:    0.08054             max:      9.154]
#     odometry_error_alpha_2_std                                             min:          0             avg:     0.1485             max:      18.24]
#     odometry_error_alpha_3_mean                                            min:  2.061e-17             avg:    0.05954             max:     0.8207]
#     odometry_error_alpha_3_std                                             min:          0             avg:    0.01594             max:      1.417]
#     odometry_error_alpha_4_mean                                            min:  1.629e-17             avg:     0.2319             max:      1.091]
#     odometry_error_alpha_4_std                                             min:          0             avg:     0.2276             max:      1.809]
#     odometry_error_version                                                 [2]
#     localization_update_absolute_translation_error_mean                    min:   0.001657             avg:     0.1001             max:      1.698]
#     localization_update_absolute_translation_error_std                     min:          0             avg:    0.04982             max:      1.557]
#     localization_update_absolute_rotation_error_mean                       min:  0.0003956             avg:     0.0267             max:      1.145]
#     localization_update_absolute_rotation_error_std                        min:          0             avg:    0.04004             max:      1.299]
#     localization_update_relative_translation_error_mean                    min:   0.001501             avg:     0.0112             max:    0.05948]
#     localization_update_relative_translation_error_std                     min:          0             avg:    0.01059             max:     0.4555]
#     localization_update_relative_rotation_error_mean                       min:  0.0002547             avg:    0.01072             max:     0.3784]
#     localization_update_relative_rotation_error_std                        min:          0             avg:    0.03476             max:     0.6973]
#     localization_update_normalized_relative_translation_error_mean         min:    0.00547             avg:    0.06296             max:       1.29]
#     localization_update_normalized_relative_translation_error_std          min:          0             avg:    0.07965             max:      9.121]
#     localization_update_normalized_relative_rotation_error_mean            min:   0.005356             avg:     0.1689             max:      12.29]
#     localization_update_normalized_relative_rotation_error_std             min:          0             avg:     0.7821             max:      43.93]
#     localization_update_error_version                                      [1]
#     localization_update_rate_mean                                          min:     0.3642             avg:      1.157             max:       37.4]
#     localization_update_rate_std                                           min:          0             avg:     0.6343             max:      14.34]
#     localization_update_rate_version                                       [1]

# %%
run_parameters_list_path = path.expanduser("~/w/ros2_ws/src/local_planning_performance_modelling/config/direct_benchmark_configurations/run_parameters_list.yaml")
g = df[(df.robot_model=='turtlebot3_waffle_performance_modelling')].groupby(run_parameters)[
    'localization_update_rate_mean', 
    'localization_update_absolute_translation_error_mean', 
    'localization_update_absolute_rotation_error_mean',
    'localization_update_normalized_relative_translation_error_mean',
    'localization_update_normalized_relative_rotation_error_mean'
].mean()

print("len(g):", len(g), "len(g.isnan):", len(g[g.localization_update_rate_mean.isna()]))
run_parameters_list = list()
for index, row in g.iterrows():
    run_parameters_dict = dict(zip(run_parameters, list(index)))
    run_parameters_dict['odometry_error'] = [run_parameters_dict['alpha_1'], run_parameters_dict['alpha_2'], run_parameters_dict['alpha_3'], run_parameters_dict['alpha_4']]
    del run_parameters_dict['alpha_1']
    del run_parameters_dict['alpha_2']
    del run_parameters_dict['alpha_3']
    del run_parameters_dict['alpha_4']
    del run_parameters_dict['amcl_alpha_factor']
    
    run_parameters_dict['localization_node'] = 'localization_generator'
    run_parameters_dict['localization_generator_update_rate'] = float(row['localization_update_rate_mean'])
    run_parameters_dict['localization_generator_translation_error'] = float(row['localization_update_absolute_translation_error_mean'])
    run_parameters_dict['localization_generator_rotation_error'] = float(row['localization_update_absolute_rotation_error_mean'])
    run_parameters_dict['localization_generator_normalized_relative_translation_error'] = float(row['localization_update_normalized_relative_translation_error_mean'])
    run_parameters_dict['localization_generator_normalized_relative_rotation_error'] = float(row['localization_update_normalized_relative_rotation_error_mean'])
    
    run_parameters_list.append(run_parameters_dict)

with open(run_parameters_list_path, 'w') as f:
    yaml.dump(run_parameters_list, f, default_flow_style=False)
    
with open(run_parameters_list_path) as f:
    for i in yaml.safe_load(f):
        for k, v in i.items():
            print(f"{k:<50}: {v}")
        print()
# Out:
# len(g): 1226 len(g.isnan): 121
# environment_name                                  : 7A-2
# global_planner_node                               : navfn
# local_planner_node                                : dwb
# localization_generator_normalized_relative_rotation_error: 0.008373873558831912
# localization_generator_normalized_relative_translation_error: 0.02022037189589289
# localization_generator_rotation_error             : 0.0049092986703593725
# localization_generator_translation_error          : 0.05668746657922405
# localization_generator_update_rate                : 1.0568395061728395
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : 7A-2
# global_planner_node                               : navfn
# local_planner_node                                : dwb
# localization_generator_normalized_relative_rotation_error: 0.01151609645248877
# localization_generator_normalized_relative_translation_error: 0.020463155423619248
# localization_generator_rotation_error             : 0.0023362599874103282
# localization_generator_translation_error          : 0.03005023434080607
# localization_generator_update_rate                : 1.0219653179190753
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : 7A-2
# global_planner_node                               : navfn
# local_planner_node                                : rpp
# localization_generator_normalized_relative_rotation_error: 0.015098597990399438
# localization_generator_normalized_relative_translation_error: 0.03840566603599487
# localization_generator_rotation_error             : 0.0048542135848662115
# localization_generator_translation_error          : 0.07249745901484632
# localization_generator_update_rate                : 0.5618659793814432
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : 7A-2
# global_planner_node                               : navfn
# local_planner_node                                : rpp
# localization_generator_normalized_relative_rotation_error: 0.015097481503799118
# localization_generator_normalized_relative_translation_error: 0.01899146868052453
# localization_generator_rotation_error             : 0.0019270774585742523
# localization_generator_translation_error          : 0.025718943836383568
# localization_generator_update_rate                : 0.5893333333333334
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : 7A-2
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.01163577577779815
# localization_generator_normalized_relative_translation_error: 0.01829249516857168
# localization_generator_rotation_error             : 0.005268791736696744
# localization_generator_translation_error          : 0.07209894278467233
# localization_generator_update_rate                : 1.295
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : 7A-2
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.010635233418586396
# localization_generator_normalized_relative_translation_error: 0.022234397877262446
# localization_generator_rotation_error             : 0.004074416210079168
# localization_generator_translation_error          : 0.07359310735812516
# localization_generator_update_rate                : 1.1082470588235296
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : 7A-2
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.010419832908951885
# localization_generator_normalized_relative_translation_error: 0.022815471765307457
# localization_generator_rotation_error             : 0.0030728746621946066
# localization_generator_translation_error          : 0.06466038351716698
# localization_generator_update_rate                : 1.1166666666666667
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : 7A-2
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.015232129005413497
# localization_generator_normalized_relative_translation_error: 0.02213476409316873
# localization_generator_rotation_error             : 0.0029349006688527304
# localization_generator_translation_error          : 0.03355012661191728
# localization_generator_update_rate                : 1.0872267441860468
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : 7A-2
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.010717637062937942
# localization_generator_normalized_relative_translation_error: 0.0308212369282818
# localization_generator_rotation_error             : 0.004754869780284964
# localization_generator_translation_error          : 0.06381192617570845
# localization_generator_update_rate                : 1.4391304347826086
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : 7A-2
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.009536684280236546
# localization_generator_normalized_relative_translation_error: 0.020938472008411386
# localization_generator_rotation_error             : 0.0015275963614051838
# localization_generator_translation_error          : 0.03152854372675348
# localization_generator_update_rate                : 1.146712574850299
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : 7A-2
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.010311240294110324
# localization_generator_normalized_relative_translation_error: 0.023752589878558918
# localization_generator_rotation_error             : 0.0045192807912832035
# localization_generator_translation_error          : 0.06608394747591279
# localization_generator_update_rate                : 1.330681818181818
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : 7A-2
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.012492641530416551
# localization_generator_normalized_relative_translation_error: 0.030607174949244483
# localization_generator_rotation_error             : 0.005343529151763234
# localization_generator_translation_error          : 0.030393503384471363
# localization_generator_update_rate                : 0.9283842794759825
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : 7A-2
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: nan
# localization_generator_normalized_relative_translation_error: nan
# localization_generator_rotation_error             : nan
# localization_generator_translation_error          : nan
# localization_generator_update_rate                : nan
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : 7A-2
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: nan
# localization_generator_normalized_relative_translation_error: nan
# localization_generator_rotation_error             : nan
# localization_generator_translation_error          : nan
# localization_generator_update_rate                : nan
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : airlab
# global_planner_node                               : navfn
# local_planner_node                                : dwb
# localization_generator_normalized_relative_rotation_error: 0.01550941315347946
# localization_generator_normalized_relative_translation_error: 0.014470643482082584
# localization_generator_rotation_error             : 0.004499634918054268
# localization_generator_translation_error          : 0.011514034299151156
# localization_generator_update_rate                : 0.8579473684210527
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : airlab
# global_planner_node                               : navfn
# local_planner_node                                : rpp
# localization_generator_normalized_relative_rotation_error: 0.02671272188656933
# localization_generator_normalized_relative_translation_error: 0.01713989472254855
# localization_generator_rotation_error             : 0.005540119433318511
# localization_generator_translation_error          : 0.010040578827334123
# localization_generator_update_rate                : 0.5000526315789473
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : airlab
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.019156853968224242
# localization_generator_normalized_relative_translation_error: 0.012846992415978772
# localization_generator_rotation_error             : 0.0019863781406772294
# localization_generator_translation_error          : 0.011570677320850929
# localization_generator_update_rate                : 1.16005
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : airlab
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.008717979609442594
# localization_generator_normalized_relative_translation_error: 0.017246576717157642
# localization_generator_rotation_error             : 0.003488602144187193
# localization_generator_translation_error          : 0.01516330887914654
# localization_generator_update_rate                : 1.2053684210526316
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : airlab
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.023241720398899487
# localization_generator_normalized_relative_translation_error: 0.02460493697580855
# localization_generator_rotation_error             : 0.0017479880725928265
# localization_generator_translation_error          : 0.021414598983592492
# localization_generator_update_rate                : 0.8269615384615384
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : airlab
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.0120938865335506
# localization_generator_normalized_relative_translation_error: 0.02458425476631842
# localization_generator_rotation_error             : 0.006604140793641832
# localization_generator_translation_error          : 0.026029741927650226
# localization_generator_update_rate                : 0.8
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : airlab
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.01081904535446936
# localization_generator_normalized_relative_translation_error: 0.0327820698564692
# localization_generator_rotation_error             : 0.0035398327075949814
# localization_generator_translation_error          : 0.01888104385822031
# localization_generator_update_rate                : 0.7148148148148147
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : airlab
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.013845591990011627
# localization_generator_normalized_relative_translation_error: 0.018347465407399725
# localization_generator_rotation_error             : 0.003409936700580814
# localization_generator_translation_error          : 0.013687089695972805
# localization_generator_update_rate                : 1.241176470588235
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : airlab
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.005355840059281916
# localization_generator_normalized_relative_translation_error: 0.0121320891736569
# localization_generator_rotation_error             : 0.0019528306055314503
# localization_generator_translation_error          : 0.021994822203619955
# localization_generator_update_rate                : 1.2106315789473685
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : airlab
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.01225324332526144
# localization_generator_normalized_relative_translation_error: 0.024791316486207898
# localization_generator_rotation_error             : 0.003827191546597662
# localization_generator_translation_error          : 0.026689902866345414
# localization_generator_update_rate                : 0.7359487179487179
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : airlab
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.01913502969827253
# localization_generator_normalized_relative_translation_error: 0.011018414573264126
# localization_generator_rotation_error             : 0.0032413711717332503
# localization_generator_translation_error          : 0.003454045927810945
# localization_generator_update_rate                : 0.7250833333333335
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : airlab
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.02621099126348861
# localization_generator_normalized_relative_translation_error: 0.03797519352878435
# localization_generator_rotation_error             : 0.0019501055334788398
# localization_generator_translation_error          : 0.018520854637259342
# localization_generator_update_rate                : 0.6786071428571427
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : airlab
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.013642758723285669
# localization_generator_normalized_relative_translation_error: 0.046358209225872665
# localization_generator_rotation_error             : 0.0034858274705211025
# localization_generator_translation_error          : 0.012782479936533094
# localization_generator_update_rate                : 0.7439999999999999
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : fr079
# global_planner_node                               : navfn
# local_planner_node                                : dwb
# localization_generator_normalized_relative_rotation_error: 0.005765316477112044
# localization_generator_normalized_relative_translation_error: 0.011598599868566572
# localization_generator_rotation_error             : 0.0003955873981177522
# localization_generator_translation_error          : 0.017756579173482126
# localization_generator_update_rate                : 1.0719999999999998
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : fr079
# global_planner_node                               : navfn
# local_planner_node                                : dwb
# localization_generator_normalized_relative_rotation_error: 4.858030443661414
# localization_generator_normalized_relative_translation_error: 0.0625436904284797
# localization_generator_rotation_error             : 0.05146299291300778
# localization_generator_translation_error          : 0.017579284346685764
# localization_generator_update_rate                : 0.9333444444444444
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : fr079
# global_planner_node                               : navfn
# local_planner_node                                : rpp
# localization_generator_normalized_relative_rotation_error: 0.01181319709922869
# localization_generator_normalized_relative_translation_error: 0.01331667863100036
# localization_generator_rotation_error             : 0.0004542568319977073
# localization_generator_translation_error          : 0.006396965084371293
# localization_generator_update_rate                : 0.5727727272727272
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : fr079
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.010546605306619636
# localization_generator_normalized_relative_translation_error: 0.013789748992951751
# localization_generator_rotation_error             : 0.0004622050085658661
# localization_generator_translation_error          : 0.016783519940096702
# localization_generator_update_rate                : 1.0434782608695652
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : fr079
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.021731491401938467
# localization_generator_normalized_relative_translation_error: 0.018797261134713632
# localization_generator_rotation_error             : 0.0031275865691913138
# localization_generator_translation_error          : 0.030845728424238817
# localization_generator_update_rate                : 1.0495333333333334
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : fr079
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.008981417540442398
# localization_generator_normalized_relative_translation_error: 0.017158983859746922
# localization_generator_rotation_error             : 0.002487022894087907
# localization_generator_translation_error          : 0.02132792831160501
# localization_generator_update_rate                : 1.004
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : fr079
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.015866685499139332
# localization_generator_normalized_relative_translation_error: 0.02058818853831296
# localization_generator_rotation_error             : 0.0020057927167559234
# localization_generator_translation_error          : 0.02906381300966077
# localization_generator_update_rate                : 0.9452631578947368
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : fr079
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.0185435120552078
# localization_generator_normalized_relative_translation_error: 0.07795596415172883
# localization_generator_rotation_error             : 0.0007970898092485246
# localization_generator_translation_error          : 0.011978293131334904
# localization_generator_update_rate                : 0.8800666666666667
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : fr079
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.012338346858506615
# localization_generator_normalized_relative_translation_error: 0.02202195145297008
# localization_generator_rotation_error             : 0.006062969893339841
# localization_generator_translation_error          : 0.0284212981994095
# localization_generator_update_rate                : 1.175868131868132
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : fr079
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: nan
# localization_generator_normalized_relative_translation_error: nan
# localization_generator_rotation_error             : nan
# localization_generator_translation_error          : nan
# localization_generator_update_rate                : nan
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : fr079
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.007201557330561995
# localization_generator_normalized_relative_translation_error: 0.031865031933688684
# localization_generator_rotation_error             : 0.0021669980736611087
# localization_generator_translation_error          : 0.021165629039191808
# localization_generator_update_rate                : 0.7837441860465115
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : fr079
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.021227037288886298
# localization_generator_normalized_relative_translation_error: 0.0170649929936538
# localization_generator_rotation_error             : 0.0013785675389434136
# localization_generator_translation_error          : 0.008496016612639655
# localization_generator_update_rate                : 0.925
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : fr079
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.05695695805726628
# localization_generator_normalized_relative_translation_error: 0.018946747323835788
# localization_generator_rotation_error             : 0.005879530907005749
# localization_generator_translation_error          : 0.02028010392976394
# localization_generator_update_rate                : 0.9758850574712644
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : intel
# global_planner_node                               : navfn
# local_planner_node                                : dwb
# localization_generator_normalized_relative_rotation_error: 0.015669005447801285
# localization_generator_normalized_relative_translation_error: 0.019054465255480168
# localization_generator_rotation_error             : 0.002727087682897761
# localization_generator_translation_error          : 0.021436171744940592
# localization_generator_update_rate                : 0.98021875
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : intel
# global_planner_node                               : navfn
# local_planner_node                                : dwb
# localization_generator_normalized_relative_rotation_error: 0.007441705239944221
# localization_generator_normalized_relative_translation_error: 0.018315164656446208
# localization_generator_rotation_error             : 0.0016470121805498355
# localization_generator_translation_error          : 0.011435806204460835
# localization_generator_update_rate                : 0.9029411764705884
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : intel
# global_planner_node                               : navfn
# local_planner_node                                : rpp
# localization_generator_normalized_relative_rotation_error: 2.1483091827783087
# localization_generator_normalized_relative_translation_error: 0.19876348426953985
# localization_generator_rotation_error             : 0.2809192161967562
# localization_generator_translation_error          : 0.03200109528203346
# localization_generator_update_rate                : 0.6131860465116279
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : intel
# global_planner_node                               : navfn
# local_planner_node                                : rpp
# localization_generator_normalized_relative_rotation_error: 0.3448525861011648
# localization_generator_normalized_relative_translation_error: 0.1086826405831114
# localization_generator_rotation_error             : 0.09107269307338203
# localization_generator_translation_error          : 0.03743580978464204
# localization_generator_update_rate                : 0.8472972972972974
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : intel
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.01771677383000356
# localization_generator_normalized_relative_translation_error: 0.01867300365893317
# localization_generator_rotation_error             : 0.002276963902526246
# localization_generator_translation_error          : 0.025930068635132787
# localization_generator_update_rate                : 1.1293669724770643
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : intel
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 2.0345262588421686
# localization_generator_normalized_relative_translation_error: 0.045040795247186884
# localization_generator_rotation_error             : 0.034565831253699976
# localization_generator_translation_error          : 0.02317516964275675
# localization_generator_update_rate                : 0.97401
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : intel
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.009673925557014705
# localization_generator_normalized_relative_translation_error: 0.02352341420422596
# localization_generator_rotation_error             : 0.002737233566397032
# localization_generator_translation_error          : 0.01807919634319193
# localization_generator_update_rate                : 0.8750000000000002
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : intel
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.4037095105302333
# localization_generator_normalized_relative_translation_error: 0.03978310767913727
# localization_generator_rotation_error             : 0.027626370947355133
# localization_generator_translation_error          : 0.02326046389379673
# localization_generator_update_rate                : 1.0152173913043478
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : intel
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.017801524974123798
# localization_generator_normalized_relative_translation_error: 0.02152649781805628
# localization_generator_rotation_error             : 0.004978374176973391
# localization_generator_translation_error          : 0.025028988200733533
# localization_generator_update_rate                : 1.1586036585365855
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : intel
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.008489972193156387
# localization_generator_normalized_relative_translation_error: 0.02652922135517052
# localization_generator_rotation_error             : 0.005202260514586934
# localization_generator_translation_error          : 0.01853923473182757
# localization_generator_update_rate                : 1.1389610389610392
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : intel
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.1768439410118268
# localization_generator_normalized_relative_translation_error: 0.04726290498862397
# localization_generator_rotation_error             : 0.029589095375538794
# localization_generator_translation_error          : 0.02887888690005577
# localization_generator_update_rate                : 0.8628495575221238
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : intel
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.006294438158223796
# localization_generator_normalized_relative_translation_error: 0.01762267069977896
# localization_generator_rotation_error             : 0.0016125734928791042
# localization_generator_translation_error          : 0.01536873813371859
# localization_generator_update_rate                : 0.9535714285714284
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : intel
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: nan
# localization_generator_normalized_relative_translation_error: nan
# localization_generator_rotation_error             : nan
# localization_generator_translation_error          : nan
# localization_generator_update_rate                : nan
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.0, 0.0, 0.0, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : intel
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: nan
# localization_generator_normalized_relative_translation_error: nan
# localization_generator_rotation_error             : nan
# localization_generator_translation_error          : nan
# localization_generator_update_rate                : nan
# localization_node                                 : localization_generator
# ...
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : office_b
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.03404937725362573
# localization_generator_normalized_relative_translation_error: 0.040483432996357684
# localization_generator_rotation_error             : 0.01243423252489106
# localization_generator_translation_error          : 0.05845565328536378
# localization_generator_update_rate                : 1.0781609195402295
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.02, 0.0, 0.02, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.045407449290246635
# localization_generator_normalized_relative_translation_error: 0.061224041487577235
# localization_generator_rotation_error             : 0.015262569886600675
# localization_generator_translation_error          : 0.05955025182607032
# localization_generator_update_rate                : 1.0380652173913043
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.05, 0.0, 0.05, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : navfn
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.06345697002864463
# localization_generator_normalized_relative_translation_error: 0.10382705436197637
# localization_generator_rotation_error             : 0.028676850128368795
# localization_generator_translation_error          : 0.08075680382631703
# localization_generator_update_rate                : 0.9742268041237112
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.1, 0.0, 0.1, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.021575231189194053
# localization_generator_normalized_relative_translation_error: 0.039515679602928434
# localization_generator_rotation_error             : 0.008417131027966799
# localization_generator_translation_error          : 0.051325168129280174
# localization_generator_update_rate                : 1.3411582278481011
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.02, 0.0, 0.02, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.05467384201205396
# localization_generator_normalized_relative_translation_error: 0.052706863722127635
# localization_generator_rotation_error             : 0.01837250060017456
# localization_generator_translation_error          : 0.07301845908291624
# localization_generator_update_rate                : 1.2047058823529408
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.05, 0.0, 0.05, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.08025477853212765
# localization_generator_normalized_relative_translation_error: 0.07513085923800249
# localization_generator_rotation_error             : 0.034519830154348945
# localization_generator_translation_error          : 0.0939996000184813
# localization_generator_update_rate                : 1.2021157894736842
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.1, 0.0, 0.1, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.06531008932618404
# localization_generator_normalized_relative_translation_error: 0.041186484548659336
# localization_generator_rotation_error             : 0.008304257241255948
# localization_generator_translation_error          : 0.0735599124079384
# localization_generator_update_rate                : 1.2831460674157302
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 20.0
# odometry_error                                    : [0.02, 0.0, 0.02, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.12081948272483825
# localization_generator_normalized_relative_translation_error: 0.058730319270932536
# localization_generator_rotation_error             : 0.020979390222633808
# localization_generator_translation_error          : 0.05480575527531288
# localization_generator_update_rate                : 0.9626168224299064
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.02, 0.0, 0.02, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.038782258357332934
# localization_generator_normalized_relative_translation_error: 0.09781364395514956
# localization_generator_rotation_error             : 0.021927148712288392
# localization_generator_translation_error          : 0.08426599846297858
# localization_generator_update_rate                : 0.9942403846153848
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.05, 0.0, 0.05, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.06989039850367937
# localization_generator_normalized_relative_translation_error: 0.10335071382771796
# localization_generator_rotation_error             : 0.032945267626025516
# localization_generator_translation_error          : 0.09158493553167328
# localization_generator_update_rate                : 0.8230287769784174
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.1, 0.0, 0.1, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 0.8365245822996016
# localization_generator_normalized_relative_translation_error: 0.07841017700470845
# localization_generator_rotation_error             : 0.05100761044600211
# localization_generator_translation_error          : 0.06588638915305843
# localization_generator_update_rate                : 0.9742138364779872
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.02, 0.0, 0.02, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: 1.3973356508619463
# localization_generator_normalized_relative_translation_error: 0.0985434085187875
# localization_generator_rotation_error             : 0.063751996385326
# localization_generator_translation_error          : 0.09794033618427186
# localization_generator_update_rate                : 0.9465431034482756
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 40.0
# odometry_error                                    : [0.05, 0.0, 0.05, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: nan
# localization_generator_normalized_relative_translation_error: nan
# localization_generator_rotation_error             : nan
# localization_generator_translation_error          : nan
# localization_generator_update_rate                : nan
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.02, 0.0, 0.02, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: nan
# localization_generator_normalized_relative_translation_error: nan
# localization_generator_rotation_error             : nan
# localization_generator_translation_error          : nan
# localization_generator_update_rate                : nan
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.05, 0.0, 0.05, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: nan
# localization_generator_normalized_relative_translation_error: nan
# localization_generator_rotation_error             : nan
# localization_generator_translation_error          : nan
# localization_generator_update_rate                : nan
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.1, 0.0, 0.1, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 0
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: nan
# localization_generator_normalized_relative_translation_error: nan
# localization_generator_rotation_error             : nan
# localization_generator_translation_error          : nan
# localization_generator_update_rate                : nan
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.02, 0.0, 0.02, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: nan
# localization_generator_normalized_relative_translation_error: nan
# localization_generator_rotation_error             : nan
# localization_generator_translation_error          : nan
# localization_generator_update_rate                : nan
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.05, 0.0, 0.05, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
#
# environment_name                                  : office_b
# global_planner_node                               : smac
# local_planner_node                                : teb
# localization_generator_normalized_relative_rotation_error: nan
# localization_generator_normalized_relative_translation_error: nan
# localization_generator_rotation_error             : nan
# localization_generator_translation_error          : nan
# localization_generator_update_rate                : nan
# localization_node                                 : localization_generator
# max_steering_angle_deg                            : 90.0
# odometry_error                                    : [0.1, 0.0, 0.1, 0.0]
# robot_model                                       : turtlebot3_waffle_performance_modelling
# run_index                                         : 1
